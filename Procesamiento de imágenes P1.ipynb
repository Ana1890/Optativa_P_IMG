# %%
import numpy as np
import cv2
import scipy

# %%
import matplotlib.pyplot as plt

# %%
imagen=cv2.imread('Koala.jpg')

# %%
#Pasamos la imágen a matriz
imagen_array=np.array(imagen)

# %%
plt.imshow(imagen_array)
plt.show()

# %%
imagen_array.shape
# Out:
# (768, 1024, 3)

# %%
plt.imshow(imagen_array[:,:,0])
plt.show()

# %%
plt.imshow(imagen_array[:,:,1])
plt.show()

# %%
plt.imshow(imagen_array[:,:,2])
plt.show()

# %%
imagen_array[:,:,0].max()
# Out:
# 255

# %%
#Para el array completo normalizamos
normalizada=cv2.normalize(imagen_array,0, 255, cv2.NORM_MINMAX, dtype=cv2.CV_32F)

# %%
normalizada.shape
# Out:
# (768, 1024, 3)

# %%
#Una componente
plt.imshow(normalizada[:,:,1])
plt.show()

# %%
import colorsys
R=normalizada[:,:,2]
G=normalizada[:,:,1]
B=normalizada[:,:,0]

YIQ=colorsys.rgb_to_yiq(R,G,B)

# %%
len(YIQ)
# Out:
# 3

# %%
R
# Out:
# array([[0.12927914, 0.13183913, 0.14079906, ..., 0.12287918, 0.1331191 ,
#         0.11775921],
#        [0.13055913, 0.13823909, 0.1356791 , ..., 0.12287918, 0.12799914,
#         0.11391924],
#        [0.1356791 , 0.13695909, 0.1356791 , ..., 0.12287918, 0.12671916,
#         0.12159919],
#        ...,
#        [0.28927806, 0.29183805, 0.2854381 , ..., 0.18303879, 0.18175879,
#         0.18815875],
#        [0.28159812, 0.27391818, 0.2662382 , ..., 0.19199872, 0.18559876,
#         0.19199872],
#        [0.27903813, 0.26751822, 0.26111826, ..., 0.1804788 , 0.1791988 ,
#         0.18687876]], dtype=float32)

# %%
YIQ[0]
# Out:
# array([[0.11491763, 0.11775921, 0.12327597, ..., 0.1192184 , 0.12799914,
#         0.11249845],
#        [0.11440564, 0.12161198, 0.1193336 , ..., 0.11893681, 0.12453037,
#         0.11030966],
#        [0.12159918, 0.12061359, 0.12126639, ..., 0.11893681, 0.12325037,
#         0.1181304 ],
#        ...,
#        [0.27028298, 0.27284297, 0.2692718 , ..., 0.16042133, 0.15121819,
#         0.15733655],
#        [0.26349902, 0.2561007 , 0.2500719 , ..., 0.16546449, 0.15713175,
#         0.16008852],
#        [0.26004308, 0.24970074, 0.24164958, ..., 0.15738775, 0.1510134 ,
#         0.15869333]], dtype=float32)

# %%
#RGB->YIQ
#2,1,0
plt.imshow(YIQ[2]*0.2)
plt.show()

# %%
#Componente 2 =Y
plt.imshow(YIQ[2]*1.5)
plt.show()

# %%
Yp=YIQ[2]*1.5

# %%
#La importancia de la información perceptual 
#que transmite cada uno de esos valores es aproximadamente 80% Y, 15% I, y 5% Q

# %%
Yp[2].max()
# Out:
# 0.00758856

# %%
Yp[2].min()
# Out:
# -0.034746587
